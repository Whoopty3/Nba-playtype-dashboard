# %%
# Import these libraries first
from IPython.display import Image, display, IFrame, Markdown
import os



display(Markdown("# NBA Playtype Analytics Dashboard"))
display(Markdown("This dashboard contains visual analyses of NBA team play types and efficiency trends from the 2015–2016 to 2024–2025 seasons. Each visualization highlights a different aspect of the league's offensive strategies."))
display(Markdown("## Two Point vs Three Point Trends"))
display(Markdown("This visualization shows how the balance between two-point and three-point shots has shifted over the past seasons."))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/Two Point vs Three Point.png"))
display(Markdown("## Playtype Frequency Over Time"))
display(Markdown("An interactive line chart showing how often different NBA play types (e.g., pick-and-rolls, isolations) have been used over time."))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/NBA_Playtype_Frequency_Over_Time"))
display(Markdown("## Playtype Efficiency Over Time"))
display(Markdown("This interactive visualization shows the evolution of scoring efficiency for each play type across the seasons."))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/NBA_Playtype_Efficiency_Over_Time"))
display(Markdown("## League Wide eFG% Trends by Zone"))
display(Markdown("This graph tracks the effective field goal percentage (eFG%) trends across different shooting zones on the court."))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/League Wide eFG% Trends by Zone.png"))
display(Markdown("## Team Play Type Comparisons"))
display(Markdown("The following charts show how different NBA teams' emphasis on each play type has shifted season by season."))

# HALF COURT SET
display(Markdown("### Half-Court Set Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/HALF___COURT_SET_Team_Comparison.png"))

# HANDOFF / DHO
display(Markdown("### Handoff / DHO Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/HANDOFF___DHO_Team_Comparison.png"))

# ISOLATION
display(Markdown("### Isolation Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/ISOLATION_Team_Comparison.png"))

# OFF BALL SCREEN
display(Markdown("### Off-Ball Screen Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/OFF_BALL_SCREEN_Team_Comparison.png"))

# OFF CUTS
display(Markdown("### Off Cuts Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/OFF_CUTS_Team_Comparison.png"))

# PICK & ROLL - BALL HANDLER
display(Markdown("### Pick & Roll - Ball Handler"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/PICK_&_ROLL___BALL_HANDLER_Team_Comparison.png"))

# PICK & ROLL - ROLL MAN
display(Markdown("### Pick & Roll - Roll Man"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/PICK_&_ROLL___ROLL_MAN_Team_Comparison.png"))

# POSTUP
display(Markdown("### Postup Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/POSTUP_Team_Comparison.png"))

# SPOTUP
display(Markdown("### Spotup Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/SPOTUP_Team_Comparison.png"))

# TRANSITION
display(Markdown("### Transition Play Type"))
display(Image(filename="/Users/paynewhitlock/Desktop/team_comparison_charts/TRANSITION_Team_Comparison.png"))
# Out:
# # NBA Playtype Analytics Dashboard
# This dashboard contains visual analyses of NBA team play types and efficiency trends from the 2015–2016 to 2024–2025 seasons. Each visualization highlights a different aspect of the league's offensive strategies.
# ## Two Point vs Three Point Trends
# This visualization shows how the balance between two-point and three-point shots has shifted over the past seasons.
# ## Playtype Frequency Over Time
# An interactive line chart showing how often different NBA play types (e.g., pick-and-rolls, isolations) have been used over time.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 14
#      12 display(Markdown("## Playtype Frequency Over Time"))
#      13 display(Markdown("An interactive line chart showing how often different NBA play types (e.g., pick-and-rolls, isolations) have been used over time."))
# ...
